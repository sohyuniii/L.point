# %%
import pandas as pd
from pandas import DataFrame, Series
import numpy as np
# Out:
# C:\ProgramData\Anaconda1\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")

# %% [markdown]
# ### 1. 상품구매 (Product)
# #### HITS_SEQ : 히트일렬번호 / PD_C : 상품코드 / PD_ADD_NM : 상품추가정보

# %%
product = pd.read_csv('Data_01.Pruduct.NoADD.csv',dtype={"CLNT_ID": np.str, "SESS_ID": np.str, "PD_C": np.str})
product.head()

# %%
product = product.drop(['Unnamed: 0'], axis=1)

# %%
product.shape
# Out:
# (5024906, 7)

# %%
dropidx = product.loc[product['HITS_SEQ']==1].index
product = product.drop(dropidx)

# %%
product.shape
# Out:
# (5019730, 7)

# %%
product.to_csv('Data_01.Pruduct.NoADDNoHit.csv',index=False,encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a8369ac09cb7> in <module>()
# ----> 1 product.to_csv('Data_01.Pruduct.NoADDNoHit.csv',index=False,encoding='utf-8')
#
# NameError: name 'product' is not defined

# %%
product = product.drop(['PD_ADD_NM'], axis=1)
product.head()
# Out:
#    CLNT_ID   SESS_ID  HITS_SEQ    PD_C PD_BRA_NM PD_BUY_AM PD_BUY_CT
# 0  4139680  07605037        12  642112     바비브라운    39,000         1
# 1  4140076  10189797        13  570603       데상트    39,000         2
# 2  4142395  06158159        85  179538       아베다    39,000         1
# 3  4144914  07935714        12  554336   아디다스 키즈    39,000         1
# 4  4144917  06406509        78  190306      데코르테    39,000         5

# %%
product.shape
# Out:
# (5024906, 8)

# %%
product.isna().sum()
# Out:
# CLNT_ID      0
# SESS_ID      0
# HITS_SEQ     0
# PD_C         0
# PD_ADD_NM    0
# PD_BRA_NM    0
# PD_BUY_AM    0
# PD_BUY_CT    0
# dtype: int64

# %%
product.sort_values(["CLNT_ID"], ascending=[True])
# Out:
#          CLNT_ID   SESS_ID  HITS_SEQ    PD_C  \
# 4855606        8   7017688        74  206218
# 4830541        8   6964877        40  206218
# 5015932       14   1156991       284  369141
# 4386392       14   1156991       284  645262
# 2346683       25   8113243         9  715121
# 2346684       25   9506206        11  715121
# 728476        25   6059256         8  715072
# 56434         25   5317297         8  598634
# 2591162       32   1136737        72   48881
# 2650245       32   1136737        72   48881
# 4430100       32   1136737        72   38697
# 1670221       32    759569        37   31974
# 1592491       32    759569        37   31982
# 1111261       33   8694850        23  613253
# 661184        33  10548225        13  605825
# 2437131       33  10300429        28  806941
# 3869892       33   8694850        23  607160
# 3859684       33   9521159        14  607160
# 3802561       51   9007214        36  777632
# 3841405       51   9007214        31  777632
# ...

# %%
product.sort_values(["HITS_SEQ"], ascending=[True])
# Out:
#          CLNT_ID   SESS_ID  HITS_SEQ    PD_C  \
# 1611373  5286992   4718757         1  697846
# 1941983  3918606   4091267         1  481378
# 3643627  5309977   9290152         1  798886
# 3643628  5309977   9308330         1  798886
# 2463987  5157021   8927609         1  463497
# 3381585  4900425   1864514         1  693731
# 508998   5545111   7755653         1  535766
# 3985340    52589    665592         1  765673
# 48660    6504912   5496343         1  219430
# 2333891  1687292   2777267         1  294254
# 1201379  1303418   5333222         1  677279
# 4192348  4946196   3334625         1  831092
# 2529121  2739475   9224463         1  737465
# 604944   2715394   6764009         1  640978
# 4969929  5097613   6265935         1  339928
# 4070958   743679  10124542         1    1043
# 3325309   454388   3054460         1  580907
# 1942616  3369761   2441170         1   60475
# 4192381  5236731  10390357         1  622248
# 4843314  1240514   8828309         1  735647
# ...

# %% [markdown]
# ### 2. 검색어 1 (Search 1)
# #### KWD_NM : 검색키워드명 / SEARCH_CNT : 검색건수

# %%
search1 = pd.read_csv('Data_02.Search1.csv', dtype={"CLNT_ID": np.str, "SESS_ID": np.str})
search1.head(10)
# Out:
#    CLNT_ID   SESS_ID      KWD_NM  SEARCH_CNT
# 0  5607714  07112876    빌리프 아이크림           6
# 1  5607714  04090791   프리메라 마스크팩           3
# 2  5607714  04090791       여성청결제           1
# 3  5612428  01876482        명품가방           1
# 4  5612428  00658123   콩순이 아이스크림           1
# 5  5612428  01876482  블루독 티셔츠 남아           1
# 6  5612471  08539312       쉬폰원피스           1
# 7  5612471  08539312  여성 쉬폰 블라우스           1
# 8  5613055  08510027      임산부 팬티           2
# 9  5613055  08510027     임산부 원피스           1

# %%
search1.head(100)
# Out:
#     CLNT_ID   SESS_ID       KWD_NM  SEARCH_CNT
# 0   5607714  07112876     빌리프 아이크림           6
# 1   5607714  04090791    프리메라 마스크팩           3
# 2   5607714  04090791        여성청결제           1
# 3   5612428  01876482         명품가방           1
# 4   5612428  00658123    콩순이 아이스크림           1
# 5   5612428  01876482   블루독 티셔츠 남아           1
# 6   5612471  08539312        쉬폰원피스           1
# 7   5612471  08539312   여성 쉬폰 블라우스           1
# 8   5613055  08510027       임산부 팬티           2
# 9   5613055  08510027      임산부 원피스           1
# 10  5609603  10483281        베베드피노          27
# 11  5609603  10483281          쁘띠뮤           6
# 12  5609603  10483281    베베드피노 티셔츠           2
# 13  5609763  06286724    남성 반팔 티셔츠           4
# 14  5609800  07380789     메트로시티 지갑           1
# 15  5609800  10249029    닥스 양말선물세트           1
# 16  5609800  07380789        크로커다일           2
# 17  5609800  07380789     크로커다일레이디           2
# 18  5609800  05655924        앤듀 셔츠           1
# ...

# %%
kkma.nouns()

# %%
search1.shape # 288만
# Out:
# (2884943, 4)

# %%
import pandas as pd
import numpy as np

# %%
search1.isna().sum()
# Out:
# CLNT_ID       0
# SESS_ID       0
# KWD_NM        0
# SEARCH_CNT    0
# dtype: int64

# %%
search1.sort_values(['CLNT_ID']).head(10)
# Out:
#          CLNT_ID   SESS_ID         KWD_NM  SEARCH_CNT
# 259302   0000014  01156991            로이드           2
# 259303   0000014  01156991             푸마           1
# 259304   0000014  01156991            빌리프           1
# 259305   0000014  01156991           푸마썬더           1
# 1116793  0000025  08113243  남성 라운드 반팔 티셔츠           9
# 1116794  0000025  06059256          황성주생식           1
# 1116795  0000025  08113243          황성주생식           2
# 1116796  0000025  05317297         레드 원피스           3
# 1116797  0000025  09506206         황성주 생식           2
# 1116798  0000025  05317297        레드 블라우스           4

# %%
search1.groupby(['CLNT_ID','SESS_ID']).agg(lambda x: x.tolist()).head()
# Out:
#                                   KWD_NM    SEARCH_CNT
# CLNT_ID SESS_ID
# 0000014 01156991    [로이드, 푸마, 빌리프, 푸마썬더]  [2, 1, 1, 1]
# 0000025 05317297       [레드 원피스, 레드 블라우스]        [3, 4]
#         06059256                 [황성주생식]           [1]
#         08113243  [남성 라운드 반팔 티셔츠, 황성주생식]        [9, 2]
#         09506206                [황성주 생식]           [2]

# %% [markdown]
# ### 3. 검색어 2 (Search 2)
# #### SESS_DT : 세션일자

# %%
import pandas as pd
search2 = pd.read_csv('Data_03.Search2.csv')
search2.head()
# Out:
#     SESS_DT     KWD_NM SEARCH_CNT
# 0  20180407      닥스원피스          8
# 1  20180407  닥터지 브라이트닝          1
# 2  20180407     달팡 인트랄          2
# 3  20180407        대상트          1
# 4  20180407       더블유닷          6

# %%
search2.shape # 805만
# Out:
# (8051172, 3)

# %%
search2.isna().sum()
# Out:
# SESS_DT       0
# KWD_NM        0
# SEARCH_CNT    0
# dtype: int64

# %%
search2['SESS_DT'].value_counts()
# Out:
# 20180514    49811
# 20180709    49378
# 20180611    49163
# 20180423    49020
# 20180501    48586
# 20180716    48134
# 20180508    47908
# 20180509    47781
# 20180610    47650
# 20180604    47588
# 20180502    47398
# 20180528    47278
# 20180513    47026
# 20180430    46978
# 20180603    46889
# 20180416    46830
# 20180515    46793
# 20180618    46788
# 20180522    46604
# 20180516    46549
# 20180626    46544
# 20180701    46530
# 20180422    46499
# 20180409    46497
# 20180507    46476
# 20180403    46431
# 20180529    46429
# 20180910    46405
# 20180625    46396
# 20180614    46331
#             ...
# 20180519    41781
# 20180731    41724
# 20180823    41717
# 20180720    41711
# 20180801    41698
# 20180714    41653
# 20180729    41644
# 20180802    41632
# 20180504    41454
# 20180919    41387
# 20180818    41259
# 20180901    41118
# 20180830    40957
# 20180721    40795
# 20180727    40739
# 20180629    40551
# 20180811    40475
# 20180825    40418
# 20180824    40400
# ...

# %%
search2['SEARCH_CNT'].max()
# Out:
# '999'

# %%
search2.loc[ search2['SEARCH_CNT'] == '999' ]
# Out:
#           SESS_DT    KWD_NM SEARCH_CNT
# 1508153  20180517       크록스        999
# 7285230  20180917  써스데이아일랜드        999

# %% [markdown]
# ### 4. 회원 (Custom)
# #### CLNT_AGE : 10대 - 10 / 20대 - 20 .....

# %%
custom = pd.read_csv('Data_04.Custom.csv',dtype={"CLNT_ID": np.str})
custom.head()
# Out:
#    CLNT_ID CLNT_GENDER  CLNT_AGE
# 0  4830726           F        30
# 1  4830874           F        40
# 2  4830975           F        30
# 3  4831275           F        30
# 4  4825325           F        30

# %%
custom['CLNT_AGE'].value_counts()
# Out:
# 30    313600
# 40    216217
# 20     95297
# 50     36624
# 60      5256
# 10      3807
# 70       846
# 80        32
# Name: CLNT_AGE, dtype: int64

# %%
custom['CLNT_GENDER'].value_counts()
# Out:
# F    570616
# M    101063
# Name: CLNT_GENDER, dtype: int64

# %%
import pandas as pd

# %% [markdown]
# ### 5. 세션 (Session)
# #### SESS_SEQ : 세션일렬번호 / TOT_PAG_VIEW_CT : 총페이지조회건수 / TOT_SESS_HR_V : 총세션시간값(s) / DVC_CTG_NM : 기기유형

# %%
session = pd.read_csv('Data_05.Session.csv', dtype={"CLNT_ID":np.str, "SESS_ID":np.str},thousands=",")
session.head()
# Out:
#    CLNT_ID   SESS_ID  SESS_SEQ   SESS_DT  TOT_PAG_VIEW_CT  TOT_SESS_HR_V  \
# 0  5873599  08641867         9  20180509             82.0         1890.0
# 1  5873599  06616320        21  20180611            105.0         1604.0
# 2  5873599  05886172        40  20180624             41.0          632.0
# 3  5873884  01050889        15  20180913            160.0         1035.0
# 4  5874461  10298270         5  20180412             13.0          298.0
#
#   DVC_CTG_NM       ZON_NM  CITY_NM
# 0     mobile      Daejeon  Daejeon
# 1     mobile        Busan    Busan
# 2     mobile      Daejeon  Daejeon
# 3     mobile  Gyeonggi-do   Anyang
# 4     mobile        Seoul    Seoul

# %%
session.shape # 271 만
# Out:
# (2712907, 9)

# %%
len(list(session['CLNT_ID'].unique())) # 92만
# Out:
# 922737

# %%
session.isna().sum()
# Out:
# CLNT_ID                0
# SESS_ID                0
# SESS_SEQ               0
# SESS_DT                0
# TOT_PAG_VIEW_CT      274
# TOT_SESS_HR_V      14202
# DVC_CTG_NM             0
# ZON_NM                 0
# CITY_NM                0
# dtype: int64

# %%
session[session.isnull().any(axis=1)].sort_values(by=['CLNT_ID'], ascending=True).head(20)
# Out:
#          CLNT_ID   SESS_ID  SESS_SEQ   SESS_DT  TOT_PAG_VIEW_CT TOT_SESS_HR_V  \
# 100223       266   2782674        12  20180814              1.0           NaN
# 142983      1179   8452834        25  20180512              1.0           NaN
# 1371190     1202   6831478         6  20180608              1.0           NaN
# 185584      1735   2042550       628  20180827              1.0           NaN
# 1425453     2137   4112419         8  20180723              1.0           NaN
# 185603      2459   7503921         5  20180528              1.0           NaN
# 185606      2459   7369192         8  20180530              1.0           NaN
# 143074      3012  10092496         3  20180415              1.0           NaN
# 1391929     3478   2794825         7  20180814              1.0           NaN
# 100273      3717  10100111         3  20180415              1.0           NaN
# 1157844     5299   8794301        43  20180507              1.0           NaN
# ...

# %%
session.loc[ session['TOT_PAG_VIEW_CT'] == 1 ].shape
# Out:
# (14225, 9)

# %%
session['TOT_PAG_VIEW_CT'].quantile([0,.25,.5,.75,1])
# Out:
# 0.00      1.0
# 0.25     29.0
# 0.50     55.0
# 0.75    108.0
# 1.00    499.0
# Name: TOT_PAG_VIEW_CT, dtype: float64

# %%
session['TOT_SESS_HR_V'].quantile([0,.25,.5,.75,1])
# Out:
# 0.00        1.0
# 0.25      415.0
# 0.50      952.0
# 0.75     1977.0
# 1.00    39329.0
# Name: TOT_SESS_HR_V, dtype: float64

# %%
session['DVC_CTG_NM'].value_counts()
# Out:
# mobile     2289681
# desktop     411169
# tablet       12057
# Name: DVC_CTG_NM, dtype: int64

# %%
device = DataFrame({'device':['mobile','desktop','tablet'],'freq':[2289681,411169,12057]})
a = device.plot.bar(x='device', y='freq', rot=0)

# %%
session['ZON_NM'].value_counts()
# Out:
# Seoul                1019843
# Gyeonggi-do           469954
# Busan                 295940
# Gyeongsangnam-do      128716
# Daegu                 116707
# Incheon               100728
# Gyeongsangbuk-do       91183
# Jeollabuk-do           78437
# Chungcheongnam-do      78072
# Gwangju                70773
# Daejeon                60442
# Jeollanam-do           49299
# Ulsan                  46584
# Chungcheongbuk-do      44455
# Gangwon-do             42701
# Jeju-do                19073
# Name: ZON_NM, dtype: int64

# %%
session['CITY_NM'].value_counts().head(10)
# Out:
# Seoul        1019842
# Busan         295940
# Daegu         116707
# Incheon       100727
# Gwangju        70773
# Daejeon        60442
# Gimhae-si      49118
# Goyang-si      47608
# Suwon-si       47120
# Ulsan          46584
# Name: CITY_NM, dtype: int64

# %% [markdown]
# ### 6. 상품분류
# #### CLAC1_NM : 상품대분류명 / CLAC2_NM : 상품중분류명 / CLAC3_NM : 상품소분류명

# %%
master = pd.read_csv('Data_06.Master.csv', dtype={"PD_C": np.str})
master.head()
# Out:
#      PD_C                                              PD_NM   CLAC1_NM  \
# 0  064382   언더아머 남성 UA HG 아머 모크 LS 1289559-001 - 블랙 / MD[95]      스포츠패션
# 1  062282                         여자 플라워덧신 2족선물세트 17403-2set  속옷/양말/홈웨어
# 2  061729                       88A2933253배트맨스웨트티 - 블랙 / 130      유아동의류
# 3  061537            닥터마틴 아드리안 블랙, 체리레드 - 02_체리레드 / 250mm(6)       패션잡화
# 4  058820  여성 그레이 스트라이프 퍼프 소매 블라우스 (128865YQ33) - 회색(앤틱실버...       남성의류
#
#     CLAC2_NM  CLAC3_NM
# 0  남성일반스포츠의류  남성스포츠티셔츠
# 1      여성양말류    여성일반양말
# 2     유아의류상의  영유아티셔츠/탑
# 3        남성화      남성부츠
# 4     남성의류상의    남성남방셔츠

# %%
import pandas as pd
import numpy as np

# %%
# 패션의류           '속옷/양말/홈웨어' , '남성의류', '여성의류  , '패션잡화', 
# 스포츠/레저        '스포츠패션' , '헬스/피트니스' , '시즌스포츠', '아웃도어/레저', '구기/필드스포츠', '자동차용품'
# 화장품/뷰티        '화장품/뷰티케어', '퍼스널케어', 
# 식품               '건강식품', '과일', '냉장식품', '축산물', '냉동식품', '음료', 
# 유아동             '출산/육아용품', '유아동의류', '완구', 
# 주방/생활/건강     '주방잡화',  '식기/조리기구', '문구/사무용품', '세제/위생', '청소/세탁/욕실용품', 
# 가구/침구/인테리어   '침구/수예', '가구', '인테리어/조명', 
# 가전/디지털        '영상/음향가전',  '계절가전', '컴퓨터', '냉장/세탁가전', '모바일', '생활/주방가전',
# 반려동물           '원예/애완', 
# 여행/서비스/금융   '상품권'

# %%
master = pd.read_csv('Data_06.Master.Col.csv', dtype={"PD_C": np.str})
master.head()
# Out:
#      PD_C                                              PD_NM   CLAC1_NM  \
# 0  064382   언더아머 남성 UA HG 아머 모크 LS 1289559-001 - 블랙 / MD[95]      스포츠패션
# 1  062282                         여자 플라워덧신 2족선물세트 17403-2set  속옷/양말/홈웨어
# 2  061729                       88A2933253배트맨스웨트티 - 블랙 / 130      유아동의류
# 3  061537            닥터마틴 아드리안 블랙, 체리레드 - 02_체리레드 / 250mm(6)       패션잡화
# 4  058820  여성 그레이 스트라이프 퍼프 소매 블라우스 (128865YQ33) - 회색(앤틱실버...       남성의류
#
#     CLAC2_NM  CLAC3_NM CLAC0_NM
# 0  남성일반스포츠의류  남성스포츠티셔츠   스포츠/레저
# 1      여성양말류    여성일반양말     패션의류
# 2     유아의류상의  영유아티셔츠/탑      유아동
# 3        남성화      남성부츠     패션의류
# 4     남성의류상의    남성남방셔츠     패션의류

# %%
master.isna().sum()
# Out:
# PD_C        0
# PD_NM       0
# CLAC1_NM    0
# CLAC2_NM    0
# CLAC3_NM    0
# dtype: int64

# %%
pd.DataFrame({'cnt':master['CLAC0_NM'].value_counts(),'percent':master['CLAC0_NM'].value_counts().values/847652})
# Out:
#                cnt   percent
# 패션의류        441562  0.520924
# 스포츠/레저      151913  0.179216
# 유아동          86629  0.102199
# 주방/생활/건강     53591  0.063223
# 화장품/뷰티       39915  0.047089
# 가구/침구/인테리어   27866  0.032874
# 가전/디지털       16476  0.019437
# 식품           14796  0.017455
# 반려동물         12940  0.015266
# 여행/서비스/금융     1964  0.002317

# %%
master['CLAC0_NM'].value_counts().sum()
# Out:
# 847652

# %%
print( len(list(master['CLAC1_NM'].unique())) )
print( list(master['CLAC1_NM'].unique()) )
# Out:
# 37
# ['스포츠패션', '속옷/양말/홈웨어', '유아동의류', '패션잡화', '남성의류', '여성의류', '건강식품', '식기/조리기구', '주방잡화', '시즌스포츠', '화장품/뷰티케어', '냉동식품', '상품권', '침구/수예', '완구', '생활/주방가전', '문구/사무용품', '퍼스널케어', '헬스/피트니스', '출산/육아용품', '계절가전', '청소/세탁/욕실용품', '원예/애완', '냉장/세탁가전', '구기/필드스포츠', '아웃도어/레저', '과일', '모바일', '세제/위생', '가구', '컴퓨터', '영상/음향가전', '냉장식품', '축산물', '음료', '인테리어/조명', '자동차용품']

# %%
master['CLAC1_NM'].value_counts()/master['CLAC1_NM'].value_counts().sum()
# Out:
# 여성의류          0.213657
# 패션잡화          0.131663
# 스포츠패션         0.123038
# 남성의류          0.102858
# 유아동의류         0.072877
# 속옷/양말/홈웨어     0.072746
# 화장품/뷰티케어      0.035405
# 시즌스포츠         0.026291
# 문구/사무용품       0.021864
# 식기/조리기구       0.020669
# 출산/육아용품       0.016860
# 침구/수예         0.015889
# 원예/애완         0.015266
# 가구            0.015032
# 아웃도어/레저       0.014612
# 완구            0.012463
# 퍼스널케어         0.011684
# 구기/필드스포츠      0.010904
# 주방잡화          0.009763
# 건강식품          0.009269
# 청소/세탁/욕실용품    0.008101
# 생활/주방가전       0.005835
# 모바일           0.004931
# 컴퓨터           0.004747
# 헬스/피트니스       0.004181
# 과일            0.003110
# 세제/위생         0.002825
# 상품권           0.002317
# 인테리어/조명       0.001954
# 냉동식품          0.001763
# 계절가전          0.001667
# 영상/음향가전       0.001305
# 음료            0.001299
# 축산물           0.001169
# 냉장/세탁가전       0.000952
# 냉장식품          0.000846
# 자동차용품         0.000190
# Name: CLAC1_NM, dtype: float64

# %%
print( len(list(master['CLAC2_NM'].unique())) )
print( list(master['CLAC2_NM'].unique()) )
# Out:
# 128
# ...

# %%
print( len(list(master['CLAC3_NM'].unique())) )
print( list(master['CLAC3_NM'].unique()) )
# Out:
# 898
# ...

# %%
product.loc[ product['PD_C'] == '567812' ]
# Out:
#          CLNT_ID   SESS_ID  HITS_SEQ    PD_C           PD_ADD_NM PD_BRA_NM  \
# 3162471  3823836  08016441        54  567812  색상:STEEL GREY / 1개     루이까또즈
# 3172470  3088032  00971803        45  567812  색상:STEEL GREY / 1개     루이까또즈
# 3221337  0555562  05246476        24  567812  색상:STEEL GREY / 1개     루이까또즈
# 3221338  3088032  00988308       109  567812  색상:STEEL GREY / 1개     루이까또즈
# 3330410  1944186  01451190       125  567812  색상:STEEL GREY / 1개     루이까또즈
# 3339902  0121229  01566250        28  567812  색상:STEEL GREY / 1개     루이까또즈
# 3339903  1356583  09042522       500  567812  색상:STEEL GREY / 1개     루이까또즈
# 3374729  0121229  01621953        26  567812  색상:STEEL GREY / 1개     루이까또즈
#
#         PD_BUY_AM PD_BUY_CT
# 3162471   337,800         1
# 3172470   337,800         1
# 3221337   337,800         1
# 3221338   337,800         1
# 3330410   337,800         1
# 3339902   337,800         1
# 3339903   337,800         1
# 3374729   337,800         1

# %%
master.loc[ master['PD_C'] == '567812' ]
# Out:
#          PD_C                        PD_NM CLAC1_NM CLAC2_NM CLAC3_NM
# 40283  567812  토트백 HL1TL03STG - STEEL GREY     패션잡화     여성가방    여성토트백

# %%
master = master.drop(['PD_NM'], axis=1)

# %%
ex = pd.merge(product,master,on=['PD_C'])
ex = pd.merge(ex,custom,on='CLNT_ID')

# %%
ex.head(10)
# Out:
#    CLNT_ID   SESS_ID  HITS_SEQ    PD_C PD_BRA_NM PD_BUY_AM PD_BUY_CT  \
# 0  4350334  02023661        77  642112     바비브라운    39,000         1
# 1  4350334  06437730        61  672266        나스    40,000         1
# 2  4350334  06613607        52  224805        나스    40,000         1
# 3  4350334  06704828       119  224805        나스    40,000         1
# 4  4350334  04313544        59  758859     퀸오브샌드    39,400         1
# 5  4350334  06231305        34  708189        나스    40,000         1
# 6  4350334  07718921        48  594142      스토어봄    39,800         1
# 7  4350334  07718921         8  605921    내추럴발란스     2,500         3
# 8  4350334  07718921         8  605921    내추럴발란스     2,500         3
# 9  4350334  10707589        14  605921    내추럴발란스     2,500         2
#
#    CLAC1_NM CLAC2_NM       CLAC3_NM CLAC0_NM CLNT_GENDER  CLNT_AGE
# 0  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터   화장품/뷰티           F        30
# 1  화장품/뷰티케어     메이크업  BB/파운데이션/컴팩트류   화장품/뷰티           F        30
# ...

# %%
f_20 = ex.loc[ex['CLNT_GENDER']=='F' ]
f_20 = f_20.loc[ f_20['CLNT_AGE']== 20]
f_20 = f_20.drop(['CLNT_GENDER','CLNT_AGE'], axis=1)

# %%
f_20.head()
# Out:
#      CLNT_ID   SESS_ID  HITS_SEQ    PD_C PD_BRA_NM PD_BUY_AM PD_BUY_CT  \
# 106  5416905  09665802        34  642112     바비브라운    39,000         1
# 107  5416905  09676809        49  642112     바비브라운    39,000         1
# 108  5416905  08080797        52  472175     바비브라운    40,000         1
# 109  5416905  09676809        49  736986      베네피트    17,000         1
# 110  5416905  04984822        60  737019      베네피트    34,000         1
#
#      CLAC1_NM CLAC2_NM       CLAC3_NM CLAC0_NM
# 106  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터   화장품/뷰티
# 107  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터   화장품/뷰티
# 108  화장품/뷰티케어     메이크업          아이섀도우   화장품/뷰티
# 109  화장품/뷰티케어     메이크업   메이크업베이스/프라이머   화장품/뷰티
# 110  화장품/뷰티케어     메이크업          아이브로우   화장품/뷰티

# %%
f_20['CLAC0_NM'].value_counts()/f_20['CLAC0_NM'].value_counts().sum()
# Out:
# 패션의류          0.357220
# 화장품/뷰티        0.299093
# 스포츠/레저        0.145764
# 식품            0.042400
# 유아동           0.038944
# 주방/생활/건강      0.032872
# 반려동물          0.030469
# 가전/디지털        0.029329
# 가구/침구/인테리어    0.019499
# 여행/서비스/금융     0.004409
# Name: CLAC0_NM, dtype: float64

# %%
f_20['CLAC0_NM'].value_counts().sum()
# Out:
# 310475

# %%
m_20['CLAC0_NM'].value_counts()/43824
# Out:
# 패션의류          0.449685
# 스포츠/레저        0.265357
# 화장품/뷰티        0.115827
# 가전/디지털        0.045318
# 식품            0.043789
# 주방/생활/건강      0.023800
# 가구/침구/인테리어    0.018666
# 유아동           0.015015
# 반려동물          0.014672
# 여행/서비스/금융     0.007872
# Name: CLAC0_NM, dtype: float64

# %%
m_20['CLAC0_NM'].value_counts().sum()
# Out:
# 43824

# %%
master['CLAC0_NM'].value_counts()/847652
# Out:
# 패션의류          0.520924
# 스포츠/레저        0.179216
# 유아동           0.102199
# 주방/생활/건강      0.063223
# 화장품/뷰티        0.047089
# 가구/침구/인테리어    0.032874
# 가전/디지털        0.019437
# 식품            0.017455
# 반려동물          0.015266
# 여행/서비스/금융     0.002317
# Name: CLAC0_NM, dtype: float64

# %%
master['CLAC0_NM'].value_counts().sum()
# Out:
# 847652

# %%
m_20 = ex.loc[ex['CLNT_GENDER']=='M' ]
m_20 = m_20.loc[ m_20['CLNT_AGE']== 20]
m_20 = m_20.drop(['CLNT_GENDER','CLNT_AGE'], axis=1)

# %%
m_20.head()
# Out:
#       CLNT_ID   SESS_ID  HITS_SEQ    PD_C  PD_BRA_NM PD_BUY_AM PD_BUY_CT  \
# 2854  3643890  07310274        77  642112      바비브라운    39,000         1
# 2855  3643890  07310274        77  672266         나스    40,000         1
# 2856  3643890  02088644        44  070305  조르지오 아르마니    45,000         1
# 2857  3643890  03734255        12  808675        나이키     9,500         1
# 2858  3643890  03734255        12  841785        나이키    13,000         1
#
#       CLAC1_NM CLAC2_NM       CLAC3_NM CLAC0_NM
# 2854  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터   화장품/뷰티
# 2855  화장품/뷰티케어     메이크업  BB/파운데이션/컴팩트류   화장품/뷰티
# 2856  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터   화장품/뷰티
# 2857     스포츠패션    스포츠잡화        스포츠선글라스   스포츠/레저
# 2858     스포츠패션    스포츠잡화      스포츠목걸이/팔찌   스포츠/레저

# %%
print( f_20.shape )
print( m_20.shape )
# Out:
# (310475, 11)
# (43824, 11)

# %%
m_50 = ex.loc[ex['CLNT_GENDER']=='M' ]
m_50 = m_50.loc[ m_50['CLNT_AGE']== 50]
m_50 = m_50.drop(['CLNT_GENDER','CLNT_AGE'], axis=1)
m_50['CLAC0_NM'].value_counts()
# Out:
# 패션의류          18533
# 스포츠/레저        11678
# 화장품/뷰티         4233
# 식품             3580
# 주방/생활/건강       2771
# 가전/디지털         1720
# 가구/침구/인테리어     1319
# 반려동물           1114
# 유아동            1033
# 여행/서비스/금융       109
# Name: CLAC0_NM, dtype: int64

# %%
m_50['CLAC0_NM'].value_counts()/m_50['CLAC0_NM'].value_counts().sum()
# Out:
# 패션의류          0.402105
# 스포츠/레저        0.253374
# 화장품/뷰티        0.091842
# 식품            0.077674
# 주방/생활/건강      0.060122
# 가전/디지털        0.037318
# 가구/침구/인테리어    0.028618
# 반려동물          0.024170
# 유아동           0.022413
# 여행/서비스/금융     0.002365
# Name: CLAC0_NM, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
m_50['CLAC0_NM'].value_counts().plot('bar')
